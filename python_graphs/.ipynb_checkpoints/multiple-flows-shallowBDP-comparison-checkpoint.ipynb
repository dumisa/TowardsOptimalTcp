# %%
# %reset
import csv
import math
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.ndimage import median_filter
import numpy as np
import pandas as pd
from scipy import signal
import statistics as stats
import matplotlib.dates as mdates
from matplotlib.transforms import Transform
from matplotlib.ticker import (
    AutoLocator, AutoMinorLocator)
from scipy import stats
import scipy.sparse as sparse
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
def weighted_average(distribution, weights):
    return round(sum([distribution[i]*weights[i] for i in range(len(distribution))])/sum(weights),2)

def import_csv(csvfilename):
    data = []
    with open(csvfilename, "r", encoding="utf-8", errors="ignore") as scraped:
        reader = csv.reader(scraped, delimiter=' ', skipinitialspace='True')
        next(reader)
        row_index = 0
        for row in reader:
            if row:  # avoid blank lines
                #row_index += 1
                #columns = [str(row_index), row[0], row[1], row[2], row[3]]
                columns = [row[0], row[1]]
                data.append(columns)

    return data

def import_csv2(csvfilename):
    data = []
    with open(csvfilename, "r", encoding="utf-8", errors="ignore") as scraped:
        reader = csv.reader(scraped, delimiter=' ', skipinitialspace='True')
        next(reader)
        row_index = 0
        for row in reader:
            if row:  # avoid blank lines
                #row_index += 1
                #columns = [str(row_index), row[0], row[1], row[2], row[3]]
                columns = [row[0], row[1], row[2], row[3], row[4], row[5], row[6], row[7], row[8],
                           row[9], row[10] ]
                data.append(columns)

    return data

def import_csv3(csvfilename):
    data = []
    with open(csvfilename, "r", encoding="utf-8", errors="ignore") as scraped:
        reader = csv.reader(scraped, delimiter=' ', skipinitialspace='True')
        next(reader)
        row_index = 0
        for row in reader:
            if row:  # avoid blank lines
                #row_index += 1
                #columns = [str(row_index), row[0], row[1], row[2], row[3]]
                columns = [row[0], row[1], row[2], row[3], row[4], row[5], row[6], row[7], row[8],
                           row[9], row[10], row[11] ]
                data.append(columns)

    return data

def import_csv4(csvfilename):
    data = []
    with open(csvfilename, "r", encoding="utf-8", errors="ignore") as scraped:
        reader = csv.reader(scraped, delimiter=' ', skipinitialspace='True')
        next(reader)
        row_index = 0
        for row in reader:
            if row:  # avoid blank lines
                #row_index += 1
                #columns = [str(row_index), row[0], row[1], row[2], row[3]]
                columns = [row[0], row[1], row[2], row[3], row[4]]
                data.append(columns)

    return data

# %%
tcp_cca = (['TcpCubic', 'TcpBbr',
            'TcpQtColFair_1.2minRTT', 'TcpQtColFair_1.5minRTT'
           ])
BDP = 172
buffer_array = [1, 172, 345, 1036, 1727, 2418, 3454] 
print(buffer_array, tcp_cca)
# Out:
# [1, 172, 345, 1036, 1727, 2418, 3454] ['TcpCubic', 'TcpBbr', 'TcpQtColFair_1.2minRTT', 'TcpQtColFair_1.5minRTT']

# %%
num_flows = 5
cwnd = {}
agg_cwnd_mean = {}
inflight = {}
rtt = {}

for algorithm in tcp_cca:
    cwnd[algorithm] = {}
    agg_cwnd_mean[algorithm] = {}
    inflight[algorithm] = {}
    rtt[algorithm] = {}

    for buffer_size in buffer_array:
        cwnd[algorithm][buffer_size] = {}
        agg_cwnd_mean[algorithm][buffer_size] = {}
        inflight[algorithm][buffer_size] = {}
        rtt[algorithm][buffer_size] = {}

# %%
cwnd_files = []
agg_cwnd_files = []
inflight_files = []
rtt_files = []
                                               
for algorithm in tcp_cca:
    print(algorithm)
    cwnd_sim_files = []
    agg_cwnd_files_ = []
    
    for buffer_size in buffer_array: 
        agg_cwnd_files_.append("../results/qt_bdp_comparison/" + str(algorithm) + "/" + 
                        str(num_flows)  + "-flows/100Mbps-20ms/" + str(buffer_size) + "p-btlqueue/" + 
                        algorithm + "-" + str(num_flows) + "-flows-100Mbps-20ms-" + str(buffer_size) +
                        "p-" + "Agg" + "-cwnd.data")
    
    agg_cwnd_files.append(agg_cwnd_files_)
# Out:
# TcpCubic
# TcpBbr
# TcpQtColFair_1.2minRTT
# TcpQtColFair_1.5minRTT

# %%
for algorithm in tcp_cca:
    cwnd[algorithm] = {}
    agg_cwnd_mean[algorithm] = {}
    inflight[algorithm] = {}
    rtt[algorithm] = {}

    for buffer_size in buffer_array:
        cwnd[algorithm][buffer_size] = {}
        agg_cwnd_mean[algorithm][buffer_size] = {}
        inflight[algorithm][buffer_size] = {}
        rtt[algorithm][buffer_size] = {}
        
        agg_cwnd_mean[algorithm][buffer_size] = {'agg_inflight': list(),
                    'aveRtt': list(), 'agg_aveThruput': list(), 'agg_aveGoodput': list(), 'PLR': list()}
    print(algorithm)
    
agg_inflight_mean = []
agg_inflight = []
aveRtt_mean = []
aveRtt = []
agg_aveThruput_last = []
agg_aveGoodput_last = []
PLR_last = []

for algorithm  in tcp_cca:
    index_alg = tcp_cca.index(algorithm)

    agg_inflight_mean_ = []
    aveRtt_mean_ = []
    agg_aveThruput_last_ = []
    agg_aveGoodput_last_ = []
    PLR_last_ = []    
    
    for buffer_size in buffer_array:
        index_buf = buffer_array.index(buffer_size)
        agg_cwnd_data_in = import_csv3(agg_cwnd_files[index_alg][index_buf])

        agg_inflight_ = []
        agg_inflight__ = []
        aveRtt_ = []
        aveRtt__ = []
        agg_aveThruput_ = []
        agg_aveGoodput_ = []
        agg_TxPkts_ = []
        agg_ReTxPkts_ = []
        PLR_ = []
        
        for row in agg_cwnd_data_in: 
            agg_inflight_.append(float(row[2]))
            aveRtt_.append(float(row[3]))
            agg_aveThruput_.append(float(row[5]))
            agg_aveGoodput_.append(float(row[7]))
            agg_TxPkts_.append(row[8])
            agg_ReTxPkts_.append(row[9])
            if float(row[8]) > 0:
                PLR_.append(float(row[9])/float(row[8]))
                        
        agg_inflight_mean_.append(pd.DataFrame(agg_inflight_).astype('float').mean()/1448)
        aveRtt_mean_.append(pd.DataFrame(aveRtt_).astype('float').mean())
        agg_aveThruput = pd.DataFrame(agg_aveThruput_).astype('float')
        agg_aveThruput_last_.append(agg_aveThruput[0][len(agg_aveThruput)-1])
        agg_aveGoodput = pd.DataFrame(agg_aveGoodput_).astype('float')
        agg_aveGoodput_last_.append(agg_aveGoodput[0][len(agg_aveGoodput)-1])
        PLR_last_.append(PLR_[-1])
        aveRtt__.append(pd.DataFrame(aveRtt_).astype('float'))
        agg_inflight__.append(pd.DataFrame( agg_inflight_).astype('float'))

    agg_inflight_mean.append(np.array(agg_inflight_mean_))
    aveRtt_mean.append(np.array(aveRtt_mean_))
    agg_aveThruput_last.append(agg_aveThruput_last_)
    agg_aveGoodput_last.append(agg_aveGoodput_last_)
    PLR_last.append(PLR_last_)
    aveRtt.append(aveRtt__)
    agg_inflight.append(agg_inflight__)
# Out:
# TcpCubic
# TcpBbr
# TcpQtColFair_1.2minRTT
# TcpQtColFair_1.5minRTT

# %%
print(agg_aveGoodput_last[1][3])
# Out:
# 92.8844

# %%
bdp1 = [agg_aveGoodput_last[0][0], agg_aveGoodput_last[1][0], agg_aveGoodput_last[2][0], 
         agg_aveGoodput_last[3][0]]
bdp172 = [agg_aveGoodput_last[0][1], agg_aveGoodput_last[1][1], agg_aveGoodput_last[2][1], 
         agg_aveGoodput_last[3][1]]
bdp345 = [agg_aveGoodput_last[0][2], agg_aveGoodput_last[1][2], agg_aveGoodput_last[2][2], 
         agg_aveGoodput_last[3][2]]
bdp1036 = [agg_aveGoodput_last[0][3], agg_aveGoodput_last[1][3], agg_aveGoodput_last[2][3], 
         agg_aveGoodput_last[3][3]]
bdp1727 = [agg_aveGoodput_last[0][4], agg_aveGoodput_last[1][4], agg_aveGoodput_last[2][4], 
         agg_aveGoodput_last[3][4]]
bdp2418 = [agg_aveGoodput_last[0][5], agg_aveGoodput_last[1][5], agg_aveGoodput_last[2][5], 
         agg_aveGoodput_last[3][5]]
bdp3454 = [agg_aveGoodput_last[0][6], agg_aveGoodput_last[1][6], agg_aveGoodput_last[2][6], 
         agg_aveGoodput_last[3][6]]

index = [
            tcp_cca[0].replace('Tcp',''),
            tcp_cca[1].replace('Tcp',''),
            tcp_cca[2].replace('minRTT','').replace('Tcp',''),
            tcp_cca[3].replace('minRTT','').replace('Tcp','')
        ]

df = pd.DataFrame({'0.05xBDP': bdp1, '0.5xBDP': bdp172, 'BDP': bdp345, '3xBDP': bdp1036, 
                   '5xBDP': bdp1727, '7xBDP': bdp2418, '10xBDP': bdp3454
                  }, index=index)

ax1 = df.plot.bar(rot=40)

ax1.yaxis.set_minor_locator(AutoMinorLocator())
ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7)
ax1.tick_params(which='minor', length=4)
ax1.grid(b=True, which='minor', linestyle='--')

plt.legend(['0.05xBDP', '0.5xBDP', 'BDP', '3xBDP', '5xBDP', '7xBDP', '10xBDP'], loc ="center right")

plt.ylabel(r'Goodput (Mbps)')
#plt.xscale('log')
#plt.xticks(x,values)
#plt.yscale('log')
#plt.ylim(40,97)
#plt.xlim(0,15)
plt.grid(True)

plt.show()
plt.savefig('multiple_bdp_comparison/5_flows_bdp_goodput_barchart.png', transparent=True)
# Out:
# /tmp/ipykernel_3801/3295415780.py:33: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax1.grid(b=True, which='minor', linestyle='--')

# %%
bdp1 = [agg_aveThruput_last[0][0], agg_aveThruput_last[1][0], agg_aveThruput_last[2][0], 
         agg_aveThruput_last[3][0]]
bdp172 = [agg_aveThruput_last[0][1], agg_aveThruput_last[1][1], agg_aveThruput_last[2][1], 
         agg_aveThruput_last[3][1]]
bdp345 = [agg_aveThruput_last[0][2], agg_aveThruput_last[1][2], agg_aveThruput_last[2][2], 
         agg_aveThruput_last[3][2]]
bdp1036 = [agg_aveThruput_last[0][3], agg_aveThruput_last[1][3], agg_aveThruput_last[2][3], 
         agg_aveThruput_last[3][3]]
bdp1727 = [agg_aveThruput_last[0][4], agg_aveThruput_last[1][4], agg_aveThruput_last[2][4], 
         agg_aveThruput_last[3][4]]
bdp2418 = [agg_aveThruput_last[0][5], agg_aveThruput_last[1][5], agg_aveThruput_last[2][5], 
         agg_aveThruput_last[3][5]]
bdp3454 = [agg_aveThruput_last[0][6], agg_aveThruput_last[1][6], agg_aveThruput_last[2][6], 
         agg_aveThruput_last[3][6]]

index = [
            tcp_cca[0].replace('Tcp',''),
            tcp_cca[1].replace('Tcp',''),
            tcp_cca[2].replace('minRTT','').replace('Tcp',''),
            tcp_cca[3].replace('minRTT','').replace('Tcp','')
        ]

df = pd.DataFrame({'0.05xBDP': bdp1, '0.5xBDP': bdp172, 'BDP': bdp345, '3xBDP': bdp1036, 
                   '5xBDP': bdp1727, '7xBDP': bdp2418, '10xBDP': bdp3454
                  }, index=index)

ax1 = df.plot.bar(rot=40)

ax1.yaxis.set_minor_locator(AutoMinorLocator())
ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7)
ax1.tick_params(which='minor', length=4)
ax1.grid(b=True, which='minor', linestyle='--')

plt.legend(['0.05xBDP', '0.5xBDP', 'BDP', '3xBDP', '5xBDP', '7xBDP', '10xBDP'], loc ="center right")

plt.ylabel(r'Thruput (Mbps)')
#plt.xscale('log')
#plt.xticks(x,values)
#plt.yscale('log')
#plt.ylim(40,97)
#plt.xlim(0,15)
plt.grid(True)

plt.show()
plt.savefig('multiple_bdp_comparison/5_flows_bdp_thruput_barchart.png', transparent=True)
# Out:
# /tmp/ipykernel_3801/3278571402.py:33: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax1.grid(b=True, which='minor', linestyle='--')

# %%
bdp1 = [PLR_last[0][0], PLR_last[1][0], PLR_last[2][0], 
         PLR_last[3][0]]
bdp172 = [PLR_last[0][1], PLR_last[1][1], PLR_last[2][1], 
         PLR_last[3][1]]
bdp345 = [PLR_last[0][2], PLR_last[1][2], PLR_last[2][2], 
         PLR_last[3][2]]
bdp1036 = [PLR_last[0][3], PLR_last[1][3], PLR_last[2][3], 
         PLR_last[3][3]]
bdp1727 = [PLR_last[0][4], PLR_last[1][4], PLR_last[2][4], 
         PLR_last[3][4]]
bdp2418 = [PLR_last[0][5], PLR_last[1][5], PLR_last[2][5], 
         PLR_last[3][5]]
bdp3454 = [PLR_last[0][6], PLR_last[1][6], PLR_last[2][6], 
         PLR_last[3][6]]

index = [
            tcp_cca[0].replace('Tcp',''),
            tcp_cca[1].replace('Tcp',''),
            tcp_cca[2].replace('minRTT','').replace('Tcp',''),
            tcp_cca[3].replace('minRTT','').replace('Tcp','')
        ]

df = pd.DataFrame({'0.05xBDP': bdp1, '0.5xBDP': bdp172, 'BDP': bdp345, '3xBDP': bdp1036, 
                   '5xBDP': bdp1727, '7xBDP': bdp2418, '10xBDP': bdp3454
                  }, index=index)

ax1 = df.plot.bar(rot=40)

ax1.yaxis.set_minor_locator(AutoMinorLocator())
ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7)
ax1.tick_params(which='minor', length=4)
ax1.grid(b=True, which='minor', linestyle='--')

plt.legend(['0.05xBDP', '0.5xBDP', 'BDP', '3xBDP', '5xBDP', '7xBDP', '10xBDP'], loc ="best")

plt.ylabel(r'PLR')
#plt.xscale('log')
#plt.xticks(x,values)
#plt.yscale('log')
#plt.ylim(0,0.1)
#plt.xlim(0,15)
plt.grid(True)

plt.show()
plt.savefig('multiple_bdp_comparison/5_flows_bdp_PLR_barchart.png', transparent=True)
# Out:
# /tmp/ipykernel_3801/435996194.py:33: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax1.grid(b=True, which='minor', linestyle='--')

# %%
bdp1 = [aveRtt_mean[0][0][0], aveRtt_mean[1][0][0], aveRtt_mean[2][0][0], 
         aveRtt_mean[3][0][0]]
bdp172 = [aveRtt_mean[0][1][0], aveRtt_mean[1][1][0], aveRtt_mean[2][1][0], 
         aveRtt_mean[3][1][0]]
bdp345 = [aveRtt_mean[0][2][0], aveRtt_mean[1][2][0], aveRtt_mean[2][2][0], 
         aveRtt_mean[3][2][0]]
bdp1036 = [aveRtt_mean[0][3][0], aveRtt_mean[1][3][0], aveRtt_mean[2][3][0], 
         aveRtt_mean[3][3][0]]
bdp1727 = [aveRtt_mean[0][4][0], aveRtt_mean[1][4][0], aveRtt_mean[2][4][0], 
         aveRtt_mean[3][4][0]]
bdp2418 = [aveRtt_mean[0][5][0], aveRtt_mean[1][5][0], aveRtt_mean[2][5][0], 
         aveRtt_mean[3][5][0]]
bdp3454 = [aveRtt_mean[0][6][0], aveRtt_mean[1][6][0], aveRtt_mean[2][6][0], 
         aveRtt_mean[3][6][0]]

index = [
            tcp_cca[0].replace('Tcp',''),
            tcp_cca[1].replace('Tcp',''),
            tcp_cca[2].replace('minRTT','').replace('Tcp',''),
            tcp_cca[3].replace('minRTT','').replace('Tcp','')
]

print(aveRtt_mean[0][1][0])
df = pd.DataFrame({'0.05xBDP': bdp1, '0.5xBDP': bdp172, 'BDP': bdp345, '3xBDP': bdp1036, 
                   '5xBDP': bdp1727, '7xBDP': bdp2418, '10xBDP': bdp3454
                  }, index=index)

ax1 = df.plot.bar(rot=40)

ax1.yaxis.set_minor_locator(AutoMinorLocator())
ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7)
ax1.tick_params(which='minor', length=4)
ax1.grid(b=True, which='minor', linestyle='--')

plt.legend(['0.05xBDP', '0.5xBDP', 'BDP', '3xBDP', '5xBDP', '7xBDP', '10xBDP'], loc ="best")

plt.ylabel(r'RTT (secs)')
#plt.xscale('log')
#plt.xticks(x,values)
#plt.yscale('log')
#plt.ylim(40,97)
#plt.xlim(0,15)
plt.grid(True)

plt.show()
plt.savefig('multiple_bdp_comparison/5_flows_rtt_thruput_barchart.png', transparent=True)
# Out:
# 0.05685348982632658
# /tmp/ipykernel_3801/1937316087.py:34: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax1.grid(b=True, which='minor', linestyle='--')

# %%
bdp1 = [agg_inflight_mean[0][0][0], agg_inflight_mean[1][0][0], agg_inflight_mean[2][0][0], 
         agg_inflight_mean[3][0][0]]
bdp172 = [agg_inflight_mean[0][1][0], agg_inflight_mean[1][1][0], agg_inflight_mean[2][1][0], 
         agg_inflight_mean[3][1][0]]
bdp345 = [agg_inflight_mean[0][2][0], agg_inflight_mean[1][2][0], agg_inflight_mean[2][2][0], 
         agg_inflight_mean[3][2][0]]
bdp1036 = [agg_inflight_mean[0][3][0], agg_inflight_mean[1][3][0], agg_inflight_mean[2][3][0], 
         agg_inflight_mean[3][3][0]]
bdp1727 = [agg_inflight_mean[0][4][0], agg_inflight_mean[1][4][0], agg_inflight_mean[2][4][0], 
         agg_inflight_mean[3][4][0]]
bdp2418 = [agg_inflight_mean[0][5][0], agg_inflight_mean[1][5][0], agg_inflight_mean[2][5][0], 
         agg_inflight_mean[3][5][0]]
bdp3454 = [agg_inflight_mean[0][6][0], agg_inflight_mean[1][6][0], agg_inflight_mean[2][6][0], 
         agg_inflight_mean[3][6][0]]

index = [
            tcp_cca[0].replace('Tcp',''),
            tcp_cca[1].replace('Tcp',''),
            tcp_cca[2].replace('minRTT','').replace('Tcp',''),
            tcp_cca[3].replace('minRTT','').replace('Tcp','')
]

print(agg_inflight_mean[0][1][0])
df = pd.DataFrame({'0.05xBDP': bdp1, '0.5xBDP': bdp172, 'BDP': bdp345, '3xBDP': bdp1036, 
                   '5xBDP': bdp1727, '7xBDP': bdp2418, '10xBDP': bdp3454
                  }, index=index)

ax1 = df.plot.bar(rot=40)

ax1.yaxis.set_minor_locator(AutoMinorLocator())
ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7)
ax1.tick_params(which='minor', length=4)
ax1.grid(b=True, which='minor', linestyle='--')

plt.legend(['0.05xBDP', '0.5xBDP', 'BDP', '3xBDP', '5xBDP', '7xBDP', '10xBDP'], loc ="best")

plt.ylabel(r'Data-in-flight (packets)')
#plt.xscale('log')
#plt.xticks(x,values)
#plt.yscale('log')
#plt.ylim(40,97)
#plt.xlim(0,15)
plt.grid(True)

plt.show()
plt.savefig('multiple_bdp_comparison/5_flows_bdp_inflight_barchart.png', transparent=True)
# Out:
# 477.78133838398145
# /tmp/ipykernel_3801/2819767836.py:34: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax1.grid(b=True, which='minor', linestyle='--')
